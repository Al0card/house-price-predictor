# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from src.data import load_data
from src.features import preprocessing_data

# %%
path = "../data/raw/train.csv"
df_raw = load_data(path)

# %%
df_raw.shape
# Out:
# (1460, 81)

# %%
X_encoded, y = preprocessing_data(df_raw)

# %%
X_encoded.isnull().sum().sort_values(ascending=False)[X_encoded.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
print("X_encoded shape: ",X_encoded.shape)
print("y shape: ",y.shape)
# Out:
# X_encoded shape:  (1460, 328)
# y shape:  (1460,)
